# %%
# Read Excel files in pandas using read_excel() method

# import pandas
import pandas as pd

# We need to get openpyxl to read an excel file

df = pd.read_excel(r"C:\Users\HP\Downloads\Dataset+Eco+Drive+Motors.xlsx")


print("our dataframe = \n", df)
# Out:
# our dataframe =
#            Customer Name  Gender    Location
# 0           Emma Wilson    Male       Leeds
# 1           James Smith    Male     Cardiff
# 2    Benjamin Hernandez  Female     Bristol
# 3     Isabella Martinez    Male     Bristol
# 4     Isabella Martinez  Female  Manchester
# ..                  ...     ...         ...
# 394          Mason King  Female     Cardiff
# 395          Mason King    Male   Edinburgh
# 396     Alexander Adams    Male     Glasgow
# 397         Lucas Clark  Female       Leeds
# 398        Sophia Davis  Female       Leeds
#
# [399 rows x 3 columns]

# %%
# Read Excel files in pandas using read_excel() method

# import pandas
import pandas as pd

# We need to get openpyxl to read an excel file

# Fix the file path by either:
# 1. Using raw string with r prefix
df = pd.read_excel(r"C:\Users\HP\Downloads\Dataset+Eco+Drive+Motors.xlsx")

# OR
# 2. Using forward slashes instead of backslashes
# df = pd.read_excel("C:/Users/HP/Downloads/Dataset+Eco+Drive+Motors.xlsx")

# OR
# 3. Escaping the backslashes by doubling them
# df = pd.read_excel("C:\\Users\\HP\\Downloads\\Dataset+Eco+Drive+Motors.xlsx")

print("our dataframe = \n", df)

# %%
#display the summary

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer Name  399 non-null    object
#  1   Gender         399 non-null    object
#  2   Location       399 non-null    object
# dtypes: object(3)
# memory usage: 9.5+ KB
# None

# %%
# display the top 5 rows dataset

print("\n Top Rows Display :\n", df.head())
# Out:
#  Top Rows Display :
#          Customer Name  Gender    Location
# 0         Emma Wilson    Male       Leeds
# 1         James Smith    Male     Cardiff
# 2  Benjamin Hernandez  Female     Bristol
# 3   Isabella Martinez    Male     Bristol
# 4   Isabella Martinez  Female  Manchester

# %%
# display the last 5 rows dataset

print("\n Last 5 Rows Display :\n", df.tail())
# Out:
#  Last 5 Rows Display :
#         Customer Name  Gender   Location
# 394       Mason King  Female    Cardiff
# 395       Mason King    Male  Edinburgh
# 396  Alexander Adams    Male    Glasgow
# 397      Lucas Clark  Female      Leeds
# 398     Sophia Davis  Female      Leeds
