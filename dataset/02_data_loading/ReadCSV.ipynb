# %%
# How to read a csv using pandas libaries using pd.read_csv() method

import pandas as pd

# The CSV file is in the parent directory
# It's named "sales car inventory.csv" not "sales.csv"
df = pd.read_csv("../sales car inventory.csv")

print("\nOur Car Inventory DB = \n", df)
# Out:
# Our Car Inventory DB =
#           Make      Model   Color    Mileage     Price      Cost
# 0       Honda     Accord     Red    63,512    $4,000    $3,000
# 1       Honda     Accord    Blue    95,135    $2,500    $2,000
# 2       Honda     Accord  Silver   101,354    $2,000    $1,500
# 3      Toyota      Camry   Black    75,006    $2,198    $1,900
# 4      Nissan     Altima   Green    69,847    $3,826    $3,000
# 5      Nissan     Altima   Green    55,233    $2,970    $2,500
# 6      Toyota    Corolla   Black    87,278    $2,224    $2,100
# 7      Toyota    Corolla    Blue   130,684    $2,798    $2,200
# 8      Toyota    Corolla  Silver    59,169    $2,160    $2,000
# 9       Honda      Civic   White   138,789    $2,723    $1,900
# 10       Ford      F-150   Black    89,073    $3,950    $3,000
# 11  Chevrolet  Silverado   Green   109,231    $4,959    $4,500
# 12  Chevrolet     Impala  Silver    87,675    $3,791    $3,500
# ...

# %%
# Display the five first row df.head()

print("\nQuick Over view of our data =\n", df.head())
# Out:
# Quick Over view of our data =
#       Make   Model   Color    Mileage     Price      Cost
# 0   Honda  Accord     Red    63,512    $4,000    $3,000
# 1   Honda  Accord    Blue    95,135    $2,500    $2,000
# 2   Honda  Accord  Silver   101,354    $2,000    $1,500
# 3  Toyota   Camry   Black    75,006    $2,198    $1,900
# 4  Nissan  Altima   Green    69,847    $3,826    $3,000

# %%
# Display the last row using df.tail()

print(df.tail())
# Out:
#       Make    Model   Color    Mileage     Price      Cost
# 19  Nissan   Maxima     Red   101,856    $2,914    $2,500
# 20    Ford   Fusion   Black    42,542    $2,659    $2,100
# 21   Dodge  Charger  Silver    34,853    $4,349    $3,500
# 22   Dodge  Charger  Silver    58,173    $4,252    $4,000
# 23   Dodge  Charger   Black   136,775    $2,090    $1,800
